# %% [markdown]
# We can use smaller batch size for some architecture but if you have a memory issue, you can use **gradient accumulation** to train you model but updating the gradient once every n smaller batches.
#
# - k-fold cross validation is similar to ensambling
#
# **Cross Entropy Loss**: For classification, we normalize the last layer usng softmax to probability and use one-hot vector to compare the target with prediction in training phase. **Binary cross entropy** si when we only have two categories (cat or not cat)
#
#
# ## Collaborative Filtering
#
# - data set of userid, movieid, rating
# - the goal is to fill in the gaps for users that has not watched movies
# - our goal is build that preference vector such that dot product of user preference and the movie.
# - we intiailize 2 latent vactor of the same size with random number for both userid and movieid and calculate their dot product. Comparing the result with the actual rating we get an idea of the accuracy and while initially the result is bad, we have NN to improve the latent vectors.
# - **collaborative filtering** is basically matrix filling
# - **embedding** means looking sth in the array. One can think that embedding as being a computational shortcut for multiplying something by a one-hot-encoded vector.
# - Weight Decay (L2 regularization) adding to your lost function the sum of all the weight squared becauise we want to compute gradients to encourage weights to be as small as possible which avoid overfitting
# - ![image.png](attachment:ff5c8501-9fa1-4aae-b1d3-0fc91ec29664.png)
# - ![image.png](attachment:840be8fb-6c98-4e91-b6e3-66e5540173a6.png)
