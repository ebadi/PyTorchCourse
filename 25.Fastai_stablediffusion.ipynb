# %% [markdown]
# # Stable diffusion
#
# Training data = Image + Noise
# Train a model to detect and find noise to remove it in the next step
#
# UNet: Input : somwhat noisy image ---> output : the noise
#
# **Autoencoder** : We create a model that reduces dimentionality of an image and then increases its dimentionality to give us the same image. (loss=MSE). This looks very much like a compression algorithm.
#
#
# ![Screenshot from 2024-07-11 11-11-03.png](attachment:4bc55eae-c418-45af-bfc8-d101ab6b1315.png)
#
# ![Screenshot from 2024-07-11 11-12-05.png](attachment:8f876b07-a98a-4b95-bd27-b5d91e3f8e6a.png)
#
# If instead of images we detect noise of latents, we call autoencoder -> VAE

# %% [markdown]
# - We can pass one hot encoded vector of the words to the model and use it as a "guidance" on what to generate.
# - We can build a text encoder and image encoder
# - Multimodal is a model that can accept several types of input.
# - CLIP text encoder: contrastive lost ... : input a text, outputs a embedding
# - Diffusion model also take a `t` parameter that works like a momentum and tells the model how much noise is present in the input

# %% [markdown]
# ## Distallation

# %%
# %timeit a = 100
# Out:
# 7.74 ns ± 0.054 ns per loop (mean ± std. dev. of 7 runs, 100,000,000 loops each)
