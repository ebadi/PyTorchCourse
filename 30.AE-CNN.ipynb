# %% [markdown]
# ## Autoencoder
# ![Screenshot%20from%202024-09-10%2008-48-44.png](attachment:Screenshot%20from%202024-09-10%2008-48-44.png)
#
# - Data cleanining (de noising, occlusion)
# - Feature extraction
# - Anomaly fraud detection
#
#
# Autoencoder with tied weight: when encoder and decoder have the same weight

# %% [markdown]
# ## Convolution
#
# ![Screenshot%20from%202024-09-10%2008-53-38.png](attachment:Screenshot%20from%202024-09-10%2008-53-38.png)
#
# Transpose convolution: for upsampling
# Convolutions are learning and then can be used for transfer learning
#
# - max pooling : downsampling,  largest value in the window.
# - mean (average) pooling : downsampling, can be expressed through conv. [[0.25 0.25] [0.25 0.25]]
#
#
# pooling, reducece dimensionality, select feature over a broader spatial area
